# %%
import requests
import pprint
import requests
from requests.exceptions import HTTPError
from datetime import datetime as dt
import pandas as pd
import numpy as np
import timeit
import time
import datetime
import copy

def git_merge_commit_branch_simple(message):
    ! git add -A
    ! git commit -m f"{message}"
    ! git push origin eric

# %%
from apis import ICO_data
ico = ICO_data()
ico_df = ico.preprocess_data()
ico_df.head()
# Out:
#              Name                                        Description  \
# Ticker
# REP         Augur         Augur is a decentralized prediction market
# LSK          Lisk  It is a cryptocurrency and decentralized appli...
# DGD     Digix DAO  A Decentralized Autonomous Organization focuse...
# WAVES       Waves  Waves helps to make the launching and coordina...
# STRAT     Stratis  Stratis was developed to help organisations de...
#
#         Price(USD)               Start                 End  ROI(Pct) Timezone  \
# Ticker
# REP          11.16 2015-08-17 00:00:00 2015-10-01 00:00:00   18.2409    UTC+0
# LSK           0.78 2016-02-22 00:00:00 2016-03-21 00:00:00    9.3831    UTC+0
# DGD          11.85 2016-03-30 12:00:00 2016-03-30 12:00:00    2.6574    UTC+0
# WAVES         0.77 2016-04-12 13:00:00 2016-05-31 13:00:00    3.1065    UTC+0
# STRAT         0.30 2016-06-21 00:00:00 2016-07-26 00:00:00   39.7913    UTC+0
#
#        Duration
# Ticker
# REP     45 days
# LSK     28 days
# ...

# %%
from apis import get_TrackICOAPI

track_df = get_TrackICOAPI()
track_df.shape
# Out:
# (24, 12)

# %%
list_of_lists = []

for ticker in track_df.index.unique().tolist():
    
    if len(track_df.index[track_df['Name'] == ticker].tolist()) != 0:
        
        list = track_df.index[track_df['Name'] == ticker].tolist()
    
    else:
        continue
    
    list_of_lists.append(list)
    
select_indicies_list = []

for ticker in track_df.index.unique().tolist():
    
    select_indices = np.where((track_df["Name"] == ticker).tolist())
    
    select_indicies_list.append(select_indices)

# %%
list_of_lists
# Out:
# [['DACX']]

# %%
select_indicies_list
# Out:
# [(array([0], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),)]

# %%
list_of_lists_watch = []

for ticker in ico_df.index.unique().tolist():
    
    if len(ico_df.index[ico_df['Name'] == ticker].tolist()) != 0:
        
        list = ico_df.index[ico_df['Name'] == ticker].tolist()
    
    else:
        continue
    
    list_of_lists_watch.append(list)
    
select_indicies_list_watch = []

for ticker in ico_df.index.unique().tolist():
    
    select_indices = np.where((ico_df["Name"] == ticker).tolist())
    
    select_indicies_list_watch.append(select_indices)

# %%
list_of_lists_watch
# Out:
# [['NEO'],
#  ['Golos'],
#  ['DIGI'],
#  ['WAX'],
#  ['SENSE'],
#  ['DIMND'],
#  ['XRED'],
#  ['NAU'],
#  ['DADI'],
#  ['DATx'],
#  ['DEEX'],
#  ['AIOM'],
#  ['CDG'],
#  ['Eroiy'],
#  ['VLB'],
#  ['COTI'],
#  ['SMRT'],
#  ['WIIX'],
#  ['CEEK'],
#  ['Arcona'],
#  ['SMOKE'],
#  ['EOS'],
#  ['ICST'],
#  ['WELL'],
#  ['EQUI'],
#  ['BEAT'],
#  ['FTEC'],
#  ['GANA'],
#  ['B21'],
#  ['IOTW'],
#  ['RAWG'],
#  ['GNY'],
#  ['M2O'],
#  ['NHCT'],
#  ['genEOS'],
#  ['MOBU'],
#  ['VANM']]

# %%
select_indicies_list_watch
# Out:
# [(array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([7], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([20], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),),
# ...

# %%
track_df.index.unique().tolist() == ico_df.index.unique().tolist()
# Out:
# False

# %%
def check_what_matches(df1,df2):
    duplicates = []
    
    for track in df1.index.unique().tolist():
        for watch in df2.index.unique().tolist():
            if track == watch:
                duplicates.append(track)
            else:
                continue
    return duplicates

# %%
check_what_matches(track_df,ico_df)
# Out:
# ['DOM']

# %%
check
# Out:
# True

# %%
merged = pd.merge(ico_df, track_df, left_index=True, right_index=True)

# %%
merged
# Out:
#           Name_x                                        Description  \
# Ticker
# DOM     Dominium  The worlds first global property platform on t...
#
#         Price(USD)             Start_x               End_x  ROI(Pct) Timezone  \
# Ticker
# DOM            0.0 2018-09-03 11:00:00 2018-12-31 11:00:00       0.0    UTC+0
#
#        Duration_x         country  platform         pre_ico_end  \
# Ticker
# DOM      119 days  Czech Republic  Ethereum 2019-10-30 09:00:00
#
#              pre_ico_start rating  status               Name_y type  \
# Ticker
# DOM    2019-09-30 10:00:00    4.1  Closed  Diamond Open Market  IEO
#
#             End_y    Start_y Duration_y     pre_Duration
# Ticker
# DOM    2020-01-10 2020-01-10     0 days 29 days 23:00:00

# %%
merged2 = pd.concat([ico_df, track_df], axis=1)
# Out:
# C:\Users\eric\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-15fb4a62a75c> in <module>
# ----> 1 merged2 = pd.concat([ico_df, track_df], axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     227                        verify_integrity=verify_integrity,
#     228                        copy=copy, sort=sort)
# --> 229     return op.get_result()
#     230
#     231
#
# ...

# %%
merged_inner = pd.merge(left=ico_df,right=track_df, left_on='Ticker', right_on='Ticker')

# %%
merged_inner
# Out:
#           Name_x                                        Description  \
# Ticker
# DOM     Dominium  The worlds first global property platform on t...
#
#         Price(USD)             Start_x               End_x  ROI(Pct) Timezone  \
# Ticker
# DOM            0.0 2018-09-03 11:00:00 2018-12-31 11:00:00       0.0    UTC+0
#
#        Duration_x         country  platform         pre_ico_end  \
# Ticker
# DOM      119 days  Czech Republic  Ethereum 2019-10-30 09:00:00
#
#              pre_ico_start rating  status               Name_y type  \
# Ticker
# DOM    2019-09-30 10:00:00    4.1  Closed  Diamond Open Market  IEO
#
#             End_y    Start_y Duration_y     pre_Duration
# Ticker
# DOM    2020-01-10 2020-01-10     0 days 29 days 23:00:00
