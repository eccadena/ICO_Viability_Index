# %%
import pandas as pd
import json
from urllib.request import Request, urlopen
import re
import datetime
from datetime import datetime as dt

# %%
#ICO Watch List API Wrapper- Can be called with 'live', 'upcoming', and 'finished' on the end for their respective lists, otherwise calls all ICO's
#No API key needed, 1sec limit per call

class ICO_data():
    
    # Initiates the object (self) and allows variables to be set for use in any of the classes funtions
    def __init__(self):
        self.url =' https://api.icowatchlist.com/public/v1/' 
        
    def get_json(self):
        '''
        Sends HTTP Request to provided url and returns a json (dictionary) object.

        Arguements: 'url' - Requires a full http address including any applicable API keys.
        '''
        request = Request(self.url, headers={'User-Agent': 'Python'})
        response = urlopen(request)
        raw_data = response.read()
        json_data = json.loads(raw_data)
        return json_data

    def get_ico_df(self):
        json_data = self.get_json()
        ico_list = json_data['ico']['finished']
        df = pd.DataFrame(ico_list)
        return df

    def preprocess_data(self):
        df.drop(columns=['icowatchlist_url', 'image', 'website_link'])
        df['Start'] = dt.strptime(ico['start_time'], "%Y-%m-%d %H:%M:%S")
        df['End'] = dt.strptime(ico['end_time'], "%Y-%m-%d %H:%M:%S")
        try:
            df['Price(USD)'] = float(ico['price_usd'])
        except:
            df['Price(USD)'] = 0
        try:
            roi = re.split('[, %]', ico['all_time_roi'])
            df['ROI'] = float(roi[0] + roi[1])
        except:
            pass

# %%
#Instantiate the boject
ico = ICO_data()

# %%
ico_df = ico.get_ico_df()

# %%
ico_df
# Out:
#     all_time_roi coin_symbol  \
# 0      2,042.81%         REP
# 1        933.49%         LSK
# 2        290.43%         DGD
# 3        310.70%       WAVES
# 4      4,246.52%       STRAT
# 5        186.30%         XTO
# 6        217.45%       INCNT
# 7      6,618.40%         NEO
# 8        -49.71%    BLOCKPAY
# 9         65.25%         1ST
# 10        61.92%         ICN
# 11       -79.52%         LKK
# 12       -98.73%         AMP
# 13       -38.35%       SNGLS
# 14            NA         NXC
# 15       -75.51%         DCT
# 16       -51.54%         GNT
# 17     2,080.00%         ARK
# 18            NA      VSLICE
# 19     3,702.04%         KMD
# 20            NA       Golos
# 21         2.76%        CREA
# 22         7.77%       WINGS
# 23       -65.20%         TKS
# 24       -93.60%        TIME
# 25     1,324.52%        QTUM
# 26       -46.73%         EDG
# 27       144.80%         RLC
# 28       -94.29%         ETT
# 29       -51.79%         GNO
# ..           ...         ...
# 713           NA         MFX
# 714           NA        NHCT
# 715           NA        TACO
# 716           NA        AXIS
# 717           NA      genEOS
# 718           NA         VLX
# 719           NA         TXO
# 720           NA         DOM
# 721           NA        None
# 722           NA          VT
# 723           NA         REB
# 724           NA         GAX
# 725           NA         DGO
# 726           NA         INX
# 727           NA         VRA
# 728           NA         GZB
# 729           NA        MOBU
# 730           NA       RECSH
# 731           NA         HUS
# 732           NA        KEYO
# 733           NA        BTMG
# 734           NA         BUY
# 735           NA        PANX
# 736           NA        LYNK
# 737           NA          RF
# 738           NA         BCV
# 739           NA         PRY
# 740           NA         WVR
# 741           NA        VANM
# 742           NA        NACL
#
#                                            description             end_time  \
# 0           Augur is a decentralized prediction market  2015-10-01 00:00:00
# 1    It is a cryptocurrency and decentralized appli...  2016-03-21 00:00:00
# 2    A Decentralized Autonomous Organization focuse...  2016-03-30 12:00:00
# 3    Waves helps to make the launching and coordina...  2016-05-31 13:00:00
# 4    Stratis was developed to help organisations de...  2016-07-26 00:00:00
# 5    Tao Network posits itself as a digital asset m...  2016-08-15 00:00:00
# 6    Incent is a blockchain based loyalty program f...  2016-09-01 00:00:00
# 7    NEO is a China based smart contract Blockchain...  2016-09-07 00:00:00
# 8    This is a retail platform that allows multicry...  2016-09-15 00:00:00
# 9    FirstBlood is a eSports matches and betting pr...  2016-09-26 12:00:00
# 10   The Iconomi platform helps users with simple m...  2016-09-26 12:00:00
# 11             Global market space based on blockchain  2016-10-09 06:00:00
# 12   Synereo is a decentralized and distributed soc...  2016-10-18 12:00:00
# 13   This is a film and television studio and also ...  2016-10-29 12:00:00
# 14                             Video Game in Real Time  2016-11-01 13:00:00
# 15            Decent is a content distribution project  2016-11-10 12:00:00
# 16   The Golem platform enables personal computers ...  2016-11-13 00:00:00
# 17   The Ark project aims to make cryptocurrency ad...  2016-12-12 00:00:00
# 18       Betting Game based on the Ethereum Blockchain  2016-12-15 02:00:00
# 19              Komodo is a decentralized ICO platform  2016-12-16 12:00:00
# 20   Golos is open source technology bringing the p...  2016-12-22 12:00:00
# 21   CreativeCoin for the registration and distribu...  2017-01-05 00:00:00
# 22   A decentralized platform for the creation mana...  2017-01-06 00:00:00
# 23   Tokes is a digital currency project for the le...  2017-01-16 12:00:00
# 24       Time based currencies on multiple blockchains  2017-02-15 13:00:00
# 25      A smart contract platform for PoS transactions  2017-03-17 00:00:00
# 26   Edgeless solves Casino transparency problems t...  2017-03-21 00:00:00
# 27   IeXec is a fully decentralized cloud based com...  2017-04-19 23:59:59
# 28   Encrypto Telecom offers solutions for secure c...  2017-04-24 00:00:00
# 29   it is an Ethereumbased prediction market that ...  2017-04-24 11:59:59
# ..                                                 ...                  ...
# 713  We are a smart contract platform with direct c...  2018-12-15 23:59:00
# 714  Blockchain Powered Ecosystem For Total Health ...  2018-12-15 23:59:00
# 715  Smart agriculture platform for sustainable foo...  2018-12-18 00:00:00
# 716  Shipper Carrier Direct Optimization Platform u...  2018-12-21 23:59:00
# 717  genEOS is a business and technology ecosystem ...  2018-12-23 16:00:00
# 718  VLUX by Verv  Creating a new energy marketplac...  2018-12-28 15:00:00
# 719  Utilities Bill Payments Made Simple Pay teleco...  2018-12-31 00:00:00
# 720  The worlds first global property platform on t...  2018-12-31 11:00:00
# 721  Bithemoth is an advanced allencompassing crypt...  2018-12-31 11:59:00
# 722  Peer to peer ridesharing built for the blockch...  2018-12-31 23:00:00
# 723  Rebooting The Global Economy Through Energy Ci...  2018-12-31 23:59:00
# 724  Using Blockchain Technology to transform the w...  2019-01-06 23:59:00
# 725  The Mobile Digital Currency Exchange to help f...  2019-01-15 00:00:00
# 726  The purest gold at a lower price tracked by ut...  2019-01-26 11:00:00
# 727  Verasity is a nextgeneration video sharing pla...  2019-01-29 23:59:00
# 728  Gigzi is a set of interconnected digital appli...  2019-01-31 00:01:00
# 729  MoBUS is a Decentralized ICO which is presenti...  2019-01-31 11:00:00
# 730  REuse Cash is aimed to create a Recycling Syst...  2019-01-31 12:00:00
# 731  HUSSY is Disrupting the Oldest Profession a di...  2019-01-31 12:00:00
# 732  A solution to solve the issues concerning secu...  2019-01-31 14:00:00
# 733  Football marketplace with AI and Players predi...  2019-01-31 23:59:00
# 734  The Buying Power of Millions in the hands of i...  2019-01-31 23:59:00
# 735  Pantercon reinvents corporate financing and su...  2019-01-31 23:59:00
# 736  Lynking the World through the power and effica...  2019-02-10 23:59:00
# 737  The Global Fintech Ecosystem being made more e...  2019-02-15 00:00:00
# 738  Blue Chip Vision BCV is an Alternative Digital...  2019-02-25 23:59:00
# 739  PRIMARY is a system created to engage cooperat...  2019-02-28 14:00:00
# 740  The universal cryptocurrency for Virtual and A...  2019-04-30 23:59:00
# 741  VANM is a local search engine for products and...  2019-05-01 00:00:00
# 742  Providing The Infrastructures For Blockchain T...  2019-05-07 06:12:00
#
#                                       icowatchlist_url  \
# 0                   https://icowatchlist.com/ico/augur
# 1                    https://icowatchlist.com/ico/lisk
# 2                https://icowatchlist.com/ico/digixdao
# 3                   https://icowatchlist.com/ico/waves
# 4                 https://icowatchlist.com/ico/stratis
# 5              https://icowatchlist.com/ico/taonetwork
# 6                  https://icowatchlist.com/ico/incent
# 7                     https://icowatchlist.com/ico/neo
# 8                https://icowatchlist.com/ico/blockpay
# 9              https://icowatchlist.com/ico/firstblood
# 10                https://icowatchlist.com/ico/iconomi
# 11                  https://icowatchlist.com/ico/lykke
# 12                https://icowatchlist.com/ico/synereo
# 13            https://icowatchlist.com/ico/singulardtv
# 14          https://icowatchlist.com/ico/beyondthevoid
# 15                 https://icowatchlist.com/ico/decent
# 16                  https://icowatchlist.com/ico/golem
# 17                    https://icowatchlist.com/ico/ark
# 18                https://icowatchlist.com/ico/vdiceio
# 19                 https://icowatchlist.com/ico/komodo
# 20                  https://icowatchlist.com/ico/golos
# 21           https://icowatchlist.com/ico/creativecoin
# 22                  https://icowatchlist.com/ico/wings
# 23                  https://icowatchlist.com/ico/tokes
# 24             https://icowatchlist.com/ico/chronobank
# 25                   https://icowatchlist.com/ico/qtum
# 26               https://icowatchlist.com/ico/edgeless
# 27                  https://icowatchlist.com/ico/iexec
# 28            https://icowatchlist.com/ico/encryptotel
# 29                 https://icowatchlist.com/ico/gnosis
# ..                                                 ...
# 713  https://icowatchlist.com/ico/modern-finance-chain
# 714                  https://icowatchlist.com/ico/nhct
# 715               https://icowatchlist.com/ico/tanibox
# 716              https://icowatchlist.com/ico/laneaxis
# 717                https://icowatchlist.com/ico/geneos
# 718             https://icowatchlist.com/ico/verv-vlux
# 719                 https://icowatchlist.com/ico/treon
# 720              https://icowatchlist.com/ico/dominium
# 721             https://icowatchlist.com/ico/bithemoth
# 722                  https://icowatchlist.com/ico/vite
# 723                https://icowatchlist.com/ico/rebglo
# 724               https://icowatchlist.com/ico/gaxcoin
# 725                https://icowatchlist.com/ico/dinngo
# 726           https://icowatchlist.com/ico/innovaminex
# 727              https://icowatchlist.com/ico/verasity
# 728                 https://icowatchlist.com/ico/gigzi
# 729                  https://icowatchlist.com/ico/mobu
# 730            https://icowatchlist.com/ico/reuse-cash
# 731              https://icowatchlist.com/ico/hussy-io
# 732           https://icowatchlist.com/ico/superwallet
# 733    https://icowatchlist.com/ico/football-bitcademy
# 734             https://icowatchlist.com/ico/buyingcom
# 735             https://icowatchlist.com/ico/pantercon
# 736           https://icowatchlist.com/ico/lynkedworld
# 737       https://icowatchlist.com/ico/raido-financial
# 738      https://icowatchlist.com/ico/blue-chip-vision
# 739               https://icowatchlist.com/ico/primary
# 740                 https://icowatchlist.com/ico/weave
# 741                  https://icowatchlist.com/ico/vanm
# 742              https://icowatchlist.com/ico/saltmine
#
#                                                  image                  name  \
# 0             https://icowatchlist.com/logos/augur.png                 Augur
# 1              https://icowatchlist.com/logos/lisk.png                  Lisk
# 2          https://icowatchlist.com/logos/digixdao.png             Digix DAO
# 3             https://icowatchlist.com/logos/waves.png                 Waves
# 4           https://icowatchlist.com/logos/stratis.png               Stratis
# 5        https://icowatchlist.com/logos/taonetwork.png           Tao Network
# 6            https://icowatchlist.com/logos/incent.png                Incent
# 7               https://icowatchlist.com/logos/neo.png                   NEO
# 8          https://icowatchlist.com/logos/blockpay.png              BlockPay
# 9        https://icowatchlist.com/logos/firstblood.png            FirstBlood
# 10          https://icowatchlist.com/logos/iconomi.png               Iconomi
# 11            https://icowatchlist.com/logos/lykke.png                 Lykke
# 12          https://icowatchlist.com/logos/synereo.png               Synereo
# 13      https://icowatchlist.com/logos/singulardtv.png           SingularDTV
# 14    https://icowatchlist.com/logos/beyondthevoid.png       Beyond The Void
# 15           https://icowatchlist.com/logos/decent.png                Decent
# 16            https://icowatchlist.com/logos/golem.png                 Golem
# 17              https://icowatchlist.com/logos/ark.png                   Ark
# 18          https://icowatchlist.com/logos/vdiceio.png              vDice.io
# 19           https://icowatchlist.com/logos/komodo.png                Komodo
# 20            https://icowatchlist.com/logos/golos.png                 Golos
# 21     https://icowatchlist.com/logos/creativecoin.png          CreativeCoin
# 22            https://icowatchlist.com/logos/wings.png                 Wings
# 23            https://icowatchlist.com/logos/tokes.png                 Tokes
# 24       https://icowatchlist.com/logos/chronobank.png            ChronoBank
# 25             https://icowatchlist.com/logos/qtum.png                  Qtum
# 26         https://icowatchlist.com/logos/edgeless.png              Edgeless
# 27            https://icowatchlist.com/logos/iexec.png                iEx.ec
# 28      https://icowatchlist.com/logos/encryptotel.png           EncryptoTel
# 29           https://icowatchlist.com/logos/gnosis.png                Gnosis
# ..                                                 ...                   ...
# 713  https://icowatchlist.com/logos/modern-finance-...  Modern Finance Chain
# 714            https://icowatchlist.com/logos/nhct.png                  NHCT
# 715         https://icowatchlist.com/logos/tanibox.png               Tanibox
# 716        https://icowatchlist.com/logos/laneaxis.png              LaneAxis
# 717          https://icowatchlist.com/logos/geneos.png                genEOS
# 718       https://icowatchlist.com/logos/verv-vlux.png           Verv (VLUX)
# 719           https://icowatchlist.com/logos/treon.png                 Treon
# 720        https://icowatchlist.com/logos/dominium.png              Dominium
# 721       https://icowatchlist.com/logos/bithemoth.png             Bithemoth
# 722            https://icowatchlist.com/logos/vite.png                  Vite
# 723          https://icowatchlist.com/logos/rebglo.png                REBGLO
# 724         https://icowatchlist.com/logos/gaxcoin.png               GaxCoin
# 725          https://icowatchlist.com/logos/dinngo.png                DINNGO
# 726     https://icowatchlist.com/logos/innovaminex.png           InnovaMinex
# 727        https://icowatchlist.com/logos/verasity.png              Verasity
# 728           https://icowatchlist.com/logos/gigzi.png                 Gigzi
# 729            https://icowatchlist.com/logos/mobu.png                  MOBU
# 730      https://icowatchlist.com/logos/reuse-cash.png            REuse cash
# 731        https://icowatchlist.com/logos/hussy-io.png              HUSSY io
# 732     https://icowatchlist.com/logos/superwallet.png           Superwallet
# 733  https://icowatchlist.com/logos/football-bitcad...    Football Bitcademy
# 734       https://icowatchlist.com/logos/buyingcom.png            Buying.com
# 735       https://icowatchlist.com/logos/pantercon.png             Pantercon
# 736     https://icowatchlist.com/logos/lynkedworld.png          Lynked.World
# 737  https://icowatchlist.com/logos/raido-financial...       Raido Financial
# 738  https://icowatchlist.com/logos/blue-chip-visio...      Blue Chip Vision
# 739         https://icowatchlist.com/logos/primary.png               PRIMARY
# 740           https://icowatchlist.com/logos/weave.png                 Weave
# 741            https://icowatchlist.com/logos/vanm.png                  VANM
# 742        https://icowatchlist.com/logos/saltmine.png              SaltMine
#
#     price_usd           start_time timezone  \
# 0       12.43  2015-08-17 00:00:00    UTC+0
# 1        0.77  2016-02-22 00:00:00    UTC+0
# 2       12.65  2016-03-30 12:00:00    UTC+0
# 3        0.77  2016-04-12 13:00:00    UTC+0
# 4        0.32  2016-06-21 00:00:00    UTC+0
# 5        0.03  2016-07-16 00:00:00    UTC+0
# 6        0.15  2016-09-01 00:00:00    UTC+0
# 7       10.68  2016-08-08 00:00:00    UTC+0
# 8        0.06  2016-08-15 00:00:00    UTC+0
# 9        0.11  2016-09-25 00:00:00    UTC+0
# 10       0.19  2016-08-25 00:00:00    UTC+0
# 11       0.01  2016-10-09 06:00:00    UTC+0
# 12       0.00  2016-09-18 00:00:00    UTC+0
# 13       0.01  2016-10-05 00:00:00    UTC+0
# 14         NA  2016-10-01 06:00:00    UTC+0
# 15       0.03  2016-10-10 00:00:00    UTC+0
# 16       0.05  2016-10-13 00:00:00    UTC+0
# 17       0.22  2016-11-07 00:00:00    UTC+0
# 18         NA  2016-11-15 00:00:00    UTC+0
# 19       0.84  2016-10-15 12:00:00    UTC+0
# 20         NA  2016-11-22 12:00:00    UTC+0
# 21       0.03  2017-03-15 00:00:00    UTC+0
# 22       0.03  2016-11-18 00:00:00    UTC+0
# 23       0.06  2016-12-12 12:00:00    UTC+0
# 24       1.92  2016-12-15 00:00:00    UTC+0
# 25       2.14  2017-03-12 00:00:00    UTC+0
# 26       0.01  2017-02-28 00:00:00    UTC+0
# 27       0.61  2017-04-19 00:00:00    UTC+0
# 28       0.00  2017-04-24 00:00:00    UTC+0
# 29      15.08  2017-04-24 00:00:00    UTC+0
# ..        ...                  ...      ...
# 713        NA  2018-10-15 12:00:00    UTC+0
# 714        NA  2018-11-15 00:00:00   UTC--5
# 715        NA  2018-07-18 00:00:00    UTC+8
# 716        NA  2018-09-21 05:00:00   UTC--7
# 717        NA  2018-06-26 16:00:00    UTC+0
# 718        NA  2018-11-19 15:00:00    UTC+1
# 719        NA  2018-06-08 00:00:00    UTC+0
# 720        NA  2018-09-03 11:00:00    UTC+0
# 721        NA  2018-11-30 12:00:00    UTC+2
# 722        NA  2018-12-15 18:00:00    UTC+0
# 723        NA  2018-12-01 00:00:00    UTC+0
# 724        NA  2018-09-08 00:00:00    UTC+0
# 725        NA  2018-12-15 00:00:00    UTC+0
# 726        NA  2018-11-26 11:00:00    UTC+1
# 727        NA  2018-11-20 12:00:00   UTC--5
# 728        NA  2018-11-23 12:00:00    UTC+0
# 729        NA  2018-12-01 11:00:00    UTC+0
# 730        NA  2019-01-01 12:00:00    UTC+0
# 731        NA  2019-01-01 12:00:00    UTC+0
# 732        NA  2018-10-01 14:00:00    UTC+1
# 733        NA  2019-01-01 00:00:00    UTC+0
# 734        NA  2018-12-01 00:00:00    UTC+0
# 735        NA  2018-12-01 00:00:00    UTC+3
# 736        NA  2019-01-20 23:59:00    UTC+2
# 737        NA  2019-01-15 00:00:00    UTC+2
# 738        NA  2018-12-27 23:59:00    UTC+0
# 739        NA  2018-09-01 14:00:00    UTC+1
# 740        NA  2019-01-01 00:00:00    UTC+0
# 741        NA  2019-01-01 00:00:00    UTC+0
# 742        NA  2019-04-07 06:12:00   UTC--7
#
#                                           website_link
# 0     https://api.icowatchlist.com/public/v1/url/augur
# 1      https://api.icowatchlist.com/public/v1/url/lisk
# 2    https://api.icowatchlist.com/public/v1/url/dig...
# 3     https://api.icowatchlist.com/public/v1/url/waves
# 4    https://api.icowatchlist.com/public/v1/url/str...
# 5    https://api.icowatchlist.com/public/v1/url/tao...
# 6    https://api.icowatchlist.com/public/v1/url/incent
# 7       https://api.icowatchlist.com/public/v1/url/neo
# 8    https://api.icowatchlist.com/public/v1/url/blo...
# 9    https://api.icowatchlist.com/public/v1/url/fir...
# 10   https://api.icowatchlist.com/public/v1/url/ico...
# 11    https://api.icowatchlist.com/public/v1/url/lykke
# 12   https://api.icowatchlist.com/public/v1/url/syn...
# 13   https://api.icowatchlist.com/public/v1/url/sin...
# 14   https://api.icowatchlist.com/public/v1/url/bey...
# 15   https://api.icowatchlist.com/public/v1/url/decent
# 16    https://api.icowatchlist.com/public/v1/url/golem
# 17      https://api.icowatchlist.com/public/v1/url/ark
# 18   https://api.icowatchlist.com/public/v1/url/vdi...
# 19   https://api.icowatchlist.com/public/v1/url/komodo
# 20    https://api.icowatchlist.com/public/v1/url/golos
# 21   https://api.icowatchlist.com/public/v1/url/cre...
# 22    https://api.icowatchlist.com/public/v1/url/wings
# 23    https://api.icowatchlist.com/public/v1/url/tokes
# 24   https://api.icowatchlist.com/public/v1/url/chr...
# 25     https://api.icowatchlist.com/public/v1/url/qtum
# 26   https://api.icowatchlist.com/public/v1/url/edg...
# 27    https://api.icowatchlist.com/public/v1/url/iexec
# 28   https://api.icowatchlist.com/public/v1/url/enc...
# 29   https://api.icowatchlist.com/public/v1/url/gnosis
# ..                                                 ...
# 713  https://api.icowatchlist.com/public/v1/url/mod...
# 714    https://api.icowatchlist.com/public/v1/url/nhct
# 715  https://api.icowatchlist.com/public/v1/url/tan...
# 716  https://api.icowatchlist.com/public/v1/url/lan...
# 717  https://api.icowatchlist.com/public/v1/url/geneos
# 718  https://api.icowatchlist.com/public/v1/url/ver...
# 719   https://api.icowatchlist.com/public/v1/url/treon
# 720  https://api.icowatchlist.com/public/v1/url/dom...
# 721  https://api.icowatchlist.com/public/v1/url/bit...
# 722    https://api.icowatchlist.com/public/v1/url/vite
# 723  https://api.icowatchlist.com/public/v1/url/rebglo
# 724  https://api.icowatchlist.com/public/v1/url/gax...
# 725  https://api.icowatchlist.com/public/v1/url/dinngo
# 726  https://api.icowatchlist.com/public/v1/url/inn...
# 727  https://api.icowatchlist.com/public/v1/url/ver...
# 728   https://api.icowatchlist.com/public/v1/url/gigzi
# 729    https://api.icowatchlist.com/public/v1/url/mobu
# 730  https://api.icowatchlist.com/public/v1/url/reu...
# 731  https://api.icowatchlist.com/public/v1/url/hus...
# 732  https://api.icowatchlist.com/public/v1/url/sup...
# 733  https://api.icowatchlist.com/public/v1/url/foo...
# 734  https://api.icowatchlist.com/public/v1/url/buy...
# 735  https://api.icowatchlist.com/public/v1/url/pan...
# 736  https://api.icowatchlist.com/public/v1/url/lyn...
# 737  https://api.icowatchlist.com/public/v1/url/rai...
# 738  https://api.icowatchlist.com/public/v1/url/blu...
# 739  https://api.icowatchlist.com/public/v1/url/pri...
# 740   https://api.icowatchlist.com/public/v1/url/weave
# 741    https://api.icowatchlist.com/public/v1/url/vanm
# 742  https://api.icowatchlist.com/public/v1/url/sal...
#
# [743 rows x 11 columns]

# %%
time = data[0]['start_time']

# %%
time = time.split(' ')

# %%
new_time = dt.strptime(time[0], "%Y-%m-%d")

# %%
df = pd.DataFrame(data)

# %%
        for ico in ico_list:
            name = ico['name']
            ticker = ico['coin_symbol']
            desc = ico['description']
            start = ico['start_time']
            end = ico['end_time']
            price = ico['price_usd'] 
            roi = ico['all_time_roi']                
        df = pd.DataFrame({
            df['Name'] = name,
            df['Ticker'] = ticker,
            df['Description'] = desc,
            df['Start'] = start,
            df['End'] = end,
            df['Price(USD)'] = price,
            df['ROI'] = roi, 
            
        })
# Out:
#   File "<ipython-input-221-fcdb9d3a62c7>", line 10
#     df['Name'] = name,
#                ^
# SyntaxError: invalid syntax

# %%
test
# Out:
# '2,042.81%'

# %%
s = re.split('[, %]', data[0]['all_time_roi'])

# %%
ss = s[0] + s[1]

# %%
float(ss)
# Out:
# 2042.81

# %%
test_df = pd.DataFrame

# %%
list = [{'1':'24234', '2':'2342', '3':'dsgvxz', '4':'fedsfs'}, {'1':'dsfadsf', '2':'23dsfaf42', '3':'safa', '4':'43535'}, {'1':'fdsf', '2':'5345', '3':'dsgvdfsgdxz', '4':'gfdg'}]

# %%
for i in list:
    test_df.append(test_df['num1'], i['1'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-216-e8c4a2e7d52a> in <module>
#       1 for i in list:
# ----> 2     test_df.append(test_df['num1'], i['1'])
#       3
#       4
#
# TypeError: 'type' object is not subscriptable
