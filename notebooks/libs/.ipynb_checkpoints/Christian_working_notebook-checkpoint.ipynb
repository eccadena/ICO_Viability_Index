# %% [markdown]
# # Imports

# %%
import pandas as pd
import json
from urllib.request import Request, urlopen, HTTPError
import re
import datetime
from datetime import datetime as dt
from bs4 import BeautifulSoup as soup
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import tweepy
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import os
import nltk
from collections import Counter
import time
from tqdm import tqdm
import sys

consumer_key = os.getenv("TWITTER_PUBLIC_API")
consumer_secret = os.getenv("TWITTER_SECRET_KEY")
nltk.download('vader_lexicon')

addl_stopwords = [',','`', '', 'rt', 'http', 'https', 'RT', 'BTC', 'bitcoin', 'ETH', 'LTC', 'XRP', 'co', 'crypto', 'blockchain', 'cryptocurrency', 'cripto', 'litecoin']
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\cscat\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# # Begin work on ICO Projects

# %%
#ICO Watch List API Wrapper- Can be called with 'live', 'upcoming', and 'finished' on the end for their respective lists, otherwise calls all ICO's
#No API key needed, 1sec limit per call

class ICO_data():
    
    # Initiates the object (self) and allows variables to be set for use in any of the classes funtions
    def __init__(self):
        self.url =' https://api.icowatchlist.com/public/v1/'
        
    def get_json(self):
        '''
        Sends HTTP Request to provided url and returns a json (dictionary) object.

        Arguements: 'url' - Requires a full http address including any applicable API keys.
        '''
        request = Request(self.url, headers={'User-Agent': 'Python'})
        response = urlopen(request)
        raw_data = response.read()
        json_data = json.loads(raw_data)
        return json_data

    def get_ico_df(self):
        '''
        Performs the 'get_json()' funtion and converts it into a Pandas DataFrame
        '''
        json_data = self.get_json()
        ico_list = json_data['ico']['finished']
        df = pd.DataFrame(ico_list)
        return df


     
    
    def preprocess_data(self):
        '''
        Performs the 'get_df' function and removes erronus columns, converts time to DateTime objects and 
        converts the numbers to floats
        '''
        df = self.get_ico_df()
        
        df.drop(columns=['icowatchlist_url', 'image', 'website_link'], inplace = True)
        reordered_columns = ['Name', 'Description', 'Price(USD)', 'Start', 'End', 'ROI(Pct)', 'Timezone']
        df.rename(columns={'all_time_roi': 'ROI(Pct)',
                           'coin_symbol': 'Ticker',
                          'description': 'Description',
                           'end_time': 'End',
                           'name': 'Name',
                           'price_usd': 'Price(USD)',
                          'start_time': 'Start',
                           'timezone': 'Timezone',
                          }, inplace=True)
        df.set_index('Ticker', inplace = True)
        df=df.reindex(columns=reordered_columns)
        #Convert the strings to datetime objects
        df['Start'] = df['Start'].apply(lambda x: dt.strptime(x, "%Y-%m-%d %H:%M:%S"))
        df['End'] = df['End'].apply(lambda x: dt.strptime(x, "%Y-%m-%d %H:%M:%S"))
        df['Price(USD)'] = df['Price(USD)'].replace("NA",'0')
        df['ROI(Pct)'] = df['ROI(Pct)'].replace('NA','0%')
        #Split the price values that are over 1,000 at the ','
        df['Price(USD)'] = df['Price(USD)'].apply(lambda x: re.split(',', x))
        #Split the roi values at their ',', and '%'
        df['ROI(Pct)'] = df['ROI(Pct)'].apply(lambda x: re.split('[, %]', x))
        #Merge the strings back that are over 1,000 and turn them into floats
        try:
            df['Price(USD)'] = df['Price(USD)'].apply(lambda x: float(x[0] + x[1])) 
        #Convert the remaining strings back to floats    
        except:
            df['Price(USD)'] = df['Price(USD)'].apply(lambda x: float(x[0]))
        
        try:
            df['ROI(Pct)'] = df['ROI(Pct)'].apply(lambda x: float(x[0] + x[1])/100) 
        except:
            df['ROI(Pct)'] = df['ROI(Pct)'].apply(lambda x: float(x[0])/100)
        #Create a duration column from the start and end dates
        df["Duration"] = df['End'] - df['Start']
        return df

# %%
  
def check_cmc(project_name):
    '''
    Check Coin Market Cap for the project, if it exists capture the current price, market cap, volume, circulating supply, total supply, ATH, ATL
    '''
    cmc_base_url = 'https://coinmarketcap.com/currencies/'
    headers={'User-Agent':"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11"} 
    request=Request(cmc_base_url + project_name, headers=headers) 
    response =urlopen(request)
    soup = BeautifulSoup(response, 'html.parser')

# %% [markdown]
# # Test ICO functions

# %%
#Instantiate the object
ico = ICO_data()

# %%
#Call the funtion and create the dateframe
clean_df = ico.preprocess_data()
clean_df.head()
# Out:
#              Name                                        Description  \
# Ticker
# REP         Augur         Augur is a decentralized prediction market
# LSK          Lisk  It is a cryptocurrency and decentralized appli...
# DGD     Digix DAO  A Decentralized Autonomous Organization focuse...
# WAVES       Waves  Waves helps to make the launching and coordina...
# STRAT     Stratis  Stratis was developed to help organisations de...
#
#         Price(USD)               Start                 End  ROI(Pct) Timezone  \
# Ticker
# REP          12.16 2015-08-17 00:00:00 2015-10-01 00:00:00   19.9569    UTC+0
# LSK           0.78 2016-02-22 00:00:00 2016-03-21 00:00:00    9.3792    UTC+0
# DGD          12.40 2016-03-30 12:00:00 2016-03-30 12:00:00    2.8272    UTC+0
# WAVES         0.80 2016-04-12 13:00:00 2016-05-31 13:00:00    3.2407    UTC+0
# STRAT         0.32 2016-06-21 00:00:00 2016-07-26 00:00:00   42.0832    UTC+0
#
#        Duration
# Ticker
# REP     45 days
# LSK     28 days
# DGD      0 days
# WAVES   49 days
# STRAT   35 days

# %% [markdown]
# # Begin work on Coin Projects

# %%
def tokenizer(text):
    """Tokenizes text."""
    addl_stopwords = ['ann', '']
    text = word_tokenize(text)
    text = [word.lower() for word in text]
    regex = re.compile("[^a-zA-Z ]")
    text = [regex.sub('', word) for word in text]
    sw = set(stopwords.words('english') + addl_stopwords)
    lemmatizer = WordNetLemmatizer()
    text = [lemmatizer.lemmatize(word) for word in text]
    clean_text = [word for word in text if word not in sw]
    return clean_text



class Coin_data():
    
    def __init__(self):
        self.btctalk_ann_url = 'https://bitcointalk.org/index.php?board=159.0'
        self.cmc_base_url = 'https://coinmarketcap.com/currencies/'
        self.cmc_coin_url = 'https://coinmarketcap.com/all/views/all/'

    def get_cmc_coins(self):
        headers={'User-Agent':"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11"} 
        request=Request(self.cmc_coin_url, headers=headers) 
        response =urlopen(request)
        soup = BeautifulSoup(response, 'html.parser')
        coin_list = soup.findAll('a' , {'class':"currency-name-container link-secondary"})
        coins = []
        for coin in coin_list:
            coins.append(coin.text)
        return coins
        
        
    def get_new_projects(self):
        '''
        Gets a list of all new projects from Bitcointalk.org that are listed on CoinMarketCap
        '''
        #Get list of coins on Coin Market Cap
        print("Getting a list of all coins on Coin Market Cap")
        coin_list = self.get_cmc_coins()
        coin_list = [coin.lower() for coin in coin_list]
        
        #Prepare BS4 to scrape bitcointalk.org announcement page
        headers={'User-Agent':"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11"} 
        request=Request(self.btctalk_ann_url, headers=headers) 
        response =urlopen(request)
        soup = BeautifulSoup(response, 'html.parser')
        
        #Create a list of all the post on the announcement page
        links = soup.findAll('a')
        
        #Capture the url for each post
        links = [url.get('href') for url in links if 'ANN' in url.text]
        
        #For loop over each url saving the content of each page to a dict key
        print('Looping over each url saving the content of each page to a dict key')
        coins = {}
        count = 0
        for url in links:
            count += 1
            headers={'User-Agent':"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11"} 
            request=Request(url, headers=headers) 
            response =urlopen(request)
            soup = BeautifulSoup(response, 'html.parser')
            coins[count] = soup
            
        #For loop over each dict key (post html page) and captive the title, as well as search the body for key words
        print('Looping over each dict key (post html page) and captive the title, as well as search the body for key words')
        count = 1
        flags = ['gaurenteed', 'profit', 'government', 'approval', 'massive', 'mega', 'rich', 'money']
        name, rating = [],[]
        for i in range(len(coins)):
            count += 1
            scam_meter = 0

            for flag in flags:
                if flag in coins[i+1].text.lower():
                    scam_meter += 1
            name += [coins[i+1].title.text]
            rating += [scam_meter]
            
        #Create a dataframe to store the title and scam rating for each post
        df = pd.DataFrame({
            'Title':name,
            'Scam_Rating':rating,
        })
        return df
#commented out so the function will still run and return a df
    '''        
        #Extract the project name from the title
        print('Verifing if coin is on Coin Market Cap and removing those that are not')
        words, names=[], []
        for i in range(len(df)):
            words += tokenizer(df['Title'][i])
            for word in words:
                if word in coin_list:
                    cmc = 0
#                    names.append(word)
                else:
                    cmc = 1
                names.append(cmc)
#                    names.append('NA')
        print(names)           
#        df['Name'] = names
#        df = df.dropna()
'''                
        
        
        #Extract the ticker from the title
        
        
        #Extract a start date from the body of each post
        
        
        #Extract an end date from the body of each post
        
        
        #Capture the offering price for each coin
        
        
        #Identify the Algo for each project
# Out:
# "        \n        #Extract the project name from the title\n        print('Verifing if coin is on Coin Market Cap and removing those that are not')\n        words, names=[], []\n        for i in range(len(df)):\n            words += tokenizer(df['Title'][i])\n            for word in words:\n                if word in coin_list:\n                    cmc = 0\n#                    names.append(word)\n                else:\n                    cmc = 1\n                names.append(cmc)\n#                    names.append('NA')\n        print(names)           \n#        df['Name'] = names\n#        df = df.dropna()\n"

# %% [markdown]
# # Test the Coin functions

# %%
#Instantiate the object
coin = Coin_data()

# %%
#Call the funtion and create the dateframe
df = coin.get_new_projects()
df.head()
# Out:
# Getting a list of all coins on Coin Market Cap
# Looping over each url saving the content of each page to a dict key
# Looping over each dict key (post html page) and captive the title, as well as search the body for key words
#                                                Title  Scam_Rating
# 0  [ANN][ICO]HoweyCoins: the only BitcoinTalk-end...            4
# 1  Users posting "joined" type posts when not req...            1
# 2  [ANN] x42 - Feeless, PoS, Masternodes/Smart Co...            3
# 3      [ANN] Datacoin - Censorship-Free Data Storage            1
# 4  [ANN][DIVI][ONE-CLICK MASTERNODES] Tiered Mast...            0

# %%
#Tokenize each Title and check if any words match the coin_names[] if so add that name to the dataframe otherwise set the name to 'NA'
print('Verifing if coin is on Coin Market Cap and removing those that are not')
words={}
for i in range(len(df)):
    words[i]=tokenizer(df['Title'][i])
words
# Out:
# Verifing if coin is on Coin Market Cap and removing those that are not
# {0: ['ico',
#   'howeycoins',
#   'bitcointalkendorsed',
#   'ico',
#   'guaranteed',
#   'profit'],
#  1: ['user',
#   'posting',
#   'joined',
#   'type',
#   'post',
#   'required',
#   'allowed',
#   'banned'],
#  2: ['x', 'feeless', 'po', 'masternodessmart', 'contractsside', 'blockchains'],
#  3: ['divi',
#   'oneclick',
#   'masternodes',
#   'tiered',
#   'masternodes',
#   'smart',
#   'wallet',
#   'live'],
#  4: ['dash',
#   'dash',
#   'dashorg',
#   'first',
#   'selffunding',
#   'selfgoverning',
#   'crypto',
#   'currency'],
#  5: ['deeponion',
#   'onion',
#   'new',
#   'private',
#   'currency',
#   'onion',
#   'discover',
#   'privacy'],
#  6: ['cyber',
#   'like',
#   'google',
#   'cybertendermintknowledge',
#   'consensus',
#   'supercomputer'],
#  7: ['kmd',
#   'dpow',
#   'komodo',
#   'open',
#   'composable',
#   'smart',
#   'chain',
#   'platform',
#   'secured',
#   'b'],
#  8: ['qredit', 'hodler', 'enterprise', 'enhanced', 'blockchain', 'suite'],
#  9: ['axe', 'decentralized', 'x', 'llmq', 'pow', 'pose'],
#  10: ['neo', 'major', 'update', 'neo', 'blockchain', 'coming'],
#  11: ['sugarchain', 'cpu', 'launching', 'utc'],
#  12: ['ticket', 'tkts', 'powargonid', 'cpugpu', 'crypto', 'ecommerce'],
#  13: ['denarius',
#   'originator',
#   'tribus',
#   'powpos',
#   'hybrid',
#   'masternodes',
#   'native',
#   'tor'],
#  14: ['bitairt',
#   'world',
#   'first',
#   'ai',
#   'art',
#   'blockchain',
#   'ce',
#   'la',
#   'vega'],
#  15: ['sign',
#   'signature',
#   'chain',
#   'blockchainbased',
#   'document',
#   'certification'],
#  16: ['espers', 'esp', 'powposhmq', 'algo', 'new', 'feature'],
#  17: ['bsv', 'bitcoin', 'sv', 'original', 'satoshi', 'vision'],
#  18: ['sinovate', 'sin', 'xx', 'gpu', 'algo', 'infinity', 'node', 'id', 'rsv'],
#  19: ['bitcoin', 'rhodium', 'xrc', 'pow', 'x', 'quarterly', 'airdrop'],
#  20: ['wunbit',
#   'crypto',
#   'gaming',
#   'arcade',
#   'spend',
#   'earn',
#   'wun',
#   'playing',
#   'game'],
#  21: ['xiropht',
#   'xiro',
#   'fast',
#   'lightweight',
#   'portable',
#   'centralized',
#   'cryptocurrency'],
#  22: ['sem', 'semux', 'official', 'thread'],
#  23: ['xsl',
#   'solo',
#   'secure',
#   'private',
#   'untraceable',
#   'pool',
#   'resistant',
#   'cryptocurrency'],
#  24: ['helios',
#   'protocol',
#   'parallel',
#   'blockchain',
#   'smart',
#   'contract',
#   'platform'],
#  25: ['ieo', 'et', 'connecting', 'global', 'entrepreneur'],
#  26: ['pirate',
#   'zksnarks',
#   'blockchain',
#   'tor',
#   'secured',
#   'dpow',
#   'btc',
#   'hashrate'],
#  27: ['sirra',
#   'sirracoin',
#   'join',
#   'solar',
#   'mining',
#   'revolution',
#   'mnposspow'],
#  28: ['storj', 'decentralized', 'storage']}

# %%
for words in words[6]:
    print(words)
# Out:
# cyber
# like
# google
# cybertendermintknowledge
# consensus
# supercomputer

# %%
for i in range(len(words)):
    for words in words[i]:
        print(words)
# Out:
# s
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-799-256d928a75fd> in <module>
#       1 for i in range(29):
# ----> 2     for words in words[i]:
#       3         print(words)
#
# IndexError: string index out of range

# %% [markdown]
# ### Code from Azerpas (github)

# %%
class ico():
	def __init__(self):
		self.hpages = 3
		self.url = "https://icobench.com/icos?filterSort=rating-desc&page="
		self.s = requests.session()
		self.book = []
		self.r = None

	def scrape(self):
		log("Scraping ICO data...")
		for i in range(1,self.hpages+1):
			req = self.s.get(self.url+str(i))
			soup = BeautifulSoup.BeautifulSoup(req.text)

			for i in soup.findAll("div",{"class":"rate color5"}):
				current_ico = (i.parent.parent)
				if not "ico_data" in str(current_ico):
					continue
				for z in current_ico.findAll("div"):
					if "Start" in z.text and "End" in z.text:
						pass
					if "Start" in z.text:
						pattern = re.compile("Start:(.*)")
						start_date = re.findall(pattern,z.text)
					if "End" in z.text:
						pattern = re.compile("End:(.*)")
						end_date = re.findall(pattern,z.text)
				for z in current_ico.findAll("a"):
					if "href" in str(z):
						pattern = re.compile('href="(.*)">')
						link = re.findall(pattern,str(z))
				title = current_ico.find("a",{"class":"name"})
				pattern = re.compile("""href="/ico/(.*)">""")
				title = re.findall(pattern,str(title))
				title = title[0].replace('-',' ').title()

				for z in current_ico.findAll("div",{"class":"content"}):
					for p in z.findAll("p"):
						description = p.text
				try:
					sep = "KYC"
					description = description.split(sep,1)[0]
				except Exception as e:
					pass

				rating = float(i.text)

				start_date = start_date[0]
				end_date = end_date[0]
				link = "https://icobench.com" + link[0]
				self.book.append({'title':title,'start':start_date,'end':end_date,'description':description,'link':link,'rating':rating})

		maxi = self.book[0]['rating']
		self.r = {'weekWinner':self.book[0]['title'],'rate':maxi}
		for i in range(0,len(self.book)):
			if self.book[i]['rating'] > maxi:
				maxi = self.book[i]['rating']
				self.r['rate'] = maxi
				self.r['weekWinner'] = self.book[i]['title']
		log("Scraped successfully")


	def syntax(self):
		message = "📈 Meilleure ICO de ces 4 derniers jours: " + self.r['weekWinner'] + " avec un score de: " + str(self.r['rate']) + "/5\n\n"
		cutting = 0
		for i in range(0,len(self.book)):
			cutting += 1
			message += "\nNom: {}\nDescription: {}\nDébut: {}\nFin: {}\nLien: {}\nNote: {}\n----------------\n".format(self.book[i]['title'],self.book[i]['description'],self.book[i]['start'],self.book[i]['end'],self.book[i]['link'],self.book[i]['rating'])
			if (cutting % 3) == 0:
				message += "+++"
		# adapted to ICObench syntax
		return message

# %% [markdown]
# ### End

# %%
ico = ICO_data()

# %%
ico_df = ico.preprocess_data()

# %%
ico_df.iloc[0]
# Out:
# Name                                                Augur
# Description    Augur is a decentralized prediction market
# Price(USD)                                          11.78
# Start                                 2015-08-17 00:00:00
# End                                   2015-10-01 00:00:00
# ROI(Pct)                                          19.3171
# Timezone                                            UTC+0
# Duration                                 45 days 00:00:00
# Name: REP, dtype: object

# %%
def tokenizer(text):
    """Tokenizes text."""
    text = word_tokenize(text)
    text = [word.lower() for word in text]
    regex = re.compile("[^a-zA-Z ]")
    text = [regex.sub('', word) for word in text]
    sw = set(stopwords.words('english') + addl_stopwords)
    lemmatizer = WordNetLemmatizer()
    text = [lemmatizer.lemmatize(word) for word in text]
    clean_text = [word for word in text if word not in sw]
    return clean_text

def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)


# Functions for Twitter


def get_tweets_list(topic_of_tweet, num_of_tweets):
    '''
    Returns a dataframe of the most recent 'N' tweets from Twitter tokenized and counted.
    
    Arguements: `topic_of_tweet` : str; what hashtag is being searched 
                'num_of_tweets' : int; how many tweet do you want returned
    '''
    text,time, word_list, word_count=[],[],[],[]
    auth = tweepy.AppAuthHandler(consumer_key, consumer_secret)
    api = tweepy.API(auth)
    for tweet in tweepy.Cursor(api.search, q=topic_of_tweet, tweet_mode='extended').items(num_of_tweets):
        text.append(tweet.full_text),
        time.append(tweet.created_at)
    tweets_df = pd.DataFrame({'Tweet':text}, index=time)
    [word_list.append(tokenizer(text)) for text in tweets_df.Tweet]
    tweets_df['Tokens'] = word_list
    [word_count.append(token_count(token)) for token in tweets_df.Tokens]
    tweets_df['Word_Count'] = word_count
    
    return tweets_df

def twitter_sent_analysis(tweet_df):    
    tweet_sentiments, comp, pos, neg, neu = [],[],[],[],[]
    analyzer = SentimentIntensityAnalyzer()
    for tweet in tweet_df.Tweet:
        sentiment = analyzer.polarity_scores(tweet),
        comp.append(sentiment[0]["compound"]),
        pos.append(sentiment[0]["pos"]),
        neg.append(sentiment[0]["neg"]),
        neu.append(sentiment[0]["neu"]),
  
    tweet_df['Compound'] = comp
    tweet_df['Positive'] = pos
    tweet_df['Negative'] = neg
    tweet_df['Neutral'] = neu

    return tweet_df

def count(df):
    '''
    Takes a DataFrame with a "compund" column and returns a basic count of positive, neutral, and negative sentiment in a dict format
    '''
    positive_count, negative_count, neutral_count = 0,0,0
    for i in df['Compound']:
        if i >= 0.05:
            positive_count += 1
        elif i <= -0.05:
            negative_count += 1
        else:
            neutral_count += 1
    count={
        'Positive Tweets': positive_count,
        'Neutral Tweets': neutral_count,
       'Negavtive Tweets': negative_count
    }
    return count

def get_twitter_scores(topic_of_tweet, num_of_tweets):
    df = get_tweets_list(topic_of_tweet, num_of_tweets)
    df = twitter_sent_analysis(df)
    
    return df

# %%
aug_twittwer_df = get_twitter_df(ico_df.index[1], 10)

# %%
def twitter_score(df):    
    scores = []
    for ico in df.Name:
        search_term = '#' + str(ico)
        print(f"Searching and Scoring {search_term}")
        tweet_df = get_twitter_scores(search_term, 20)
        score = {ico :{
                'Compound' : tweet_df.Compound.mean(),
                'Positive' : tweet_df.Positive.mean(),
                'Negative' : tweet_df.Negative.mean(),
                'Neutral' : tweet_df.Neutral.mean(),
        }}
        scores.append(score)
        print(f"{ico} scored")
    print(f"Scoring of {len(scores)} tweet concluded, creating dataframe")
    
    return scores

# %%
test_df = ico_df[0:5]

# %%
test_df
# Out:
#              Name                                        Description  \
# Ticker
# REP         Augur         Augur is a decentralized prediction market
# LSK          Lisk  It is a cryptocurrency and decentralized appli...
# DGD     Digix DAO  A Decentralized Autonomous Organization focuse...
# WAVES       Waves  Waves helps to make the launching and coordina...
# STRAT     Stratis  Stratis was developed to help organisations de...
#
#         Price(USD)               Start                 End  ROI(Pct) Timezone  \
# Ticker
# REP          11.78 2015-08-17 00:00:00 2015-10-01 00:00:00   19.3171    UTC+0
# LSK           0.75 2016-02-22 00:00:00 2016-03-21 00:00:00    9.0686    UTC+0
# DGD          12.06 2016-03-30 12:00:00 2016-03-30 12:00:00    2.7222    UTC+0
# WAVES         0.78 2016-04-12 13:00:00 2016-05-31 13:00:00    3.1315    UTC+0
# STRAT         0.30 2016-06-21 00:00:00 2016-07-26 00:00:00   40.5825    UTC+0
#
#        Duration
# Ticker
# REP     45 days
# LSK     28 days
# DGD      0 days
# WAVES   49 days
# STRAT   35 days

# %%
x = twitter_score(test_df)
# Out:
# Searching and Scoring #Augur
# Augur scored
# Searching and Scoring #Lisk
# Lisk scored
# Searching and Scoring #Digix DAO
# Digix DAO scored
# Searching and Scoring #Waves
# Waves scored
# Searching and Scoring #Stratis
# Stratis scored
# Scoring of 5 tweet concluded, creating dataframe

# %%
b=pd.DataFrame()
b.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for item in x:
    t=pd.DataFrame.from_dict(item).T
    b = pd.concat([b,t], sort=True)
    b.head()

# %%
b
# Out:
#            Compound  Negative  Neutral  Positive
# Augur      0.112270   0.00440   0.9578   0.03780
# Lisk       0.044040   0.00000   0.9740   0.02600
# Digix DAO       NaN       NaN      NaN       NaN
# Waves      0.105365   0.00235   0.9635   0.03415
# Stratis         NaN       NaN      NaN       NaN

# %%
x ={
    'Compuond' : aug_twittwer_df['Compound'].mean(),
    'Positive' : aug_twittwer_df['Positive'].mean(),
    'Negative' : aug_twittwer_df['Negative'].mean(),
    'Neutral' : aug_twittwer_df['Neutral'].mean(),
}

# %%
aug_twittwer_df.append(x, ignore_index=True)
# Out:
#                                                 Tweet  \
# 0   RT @SEGreenhalgh: With our partners @FSFP @pub...
# 1   RT @MSNBC: A referee says Dr. Richard Strauss ...
# 2   RT @CLOUDFESS: Cf followan dengan somi? Rt or rep
# 3   RT @RPAutoBase: Rpa followan dengan somi? Rt o...
# 4   RT @CLOUDFESS: Cf followan dengan somi? Rt or rep
# 5   RT @majestirc: MJS fambest sama shuha? Rep aja...
# 6   RT @RPAutoBase: Rpa followan dengan somi? Rt o...
# 7   RT @AUTOTLS2: TLS  followan? Rt, jfb yo. Fambe...
# 8   RT @majestirc: MJS fambest sama shuha? Rep aja...
# 9   RT @RepSusieLee: 🚨PASSED!🚨My bipartisan bill, ...
# 10                                                NaN
#
#                                                Tokens  \
# 0   [segreenhalgh, partner, fsfp, publiccitizen, n...
# 1   [msnbc, referee, say, dr, richard, strauss, ma...
# 2        [cloudfess, cf, followan, dengan, somi, rep]
# 3      [rpautobase, rpa, followan, dengan, somi, rep]
# 4        [cloudfess, cf, followan, dengan, somi, rep]
# 5   [majestirc, mjs, fambest, sama, shuha, rep, aj...
# 6      [rpautobase, rpa, followan, dengan, somi, rep]
# 7   [autotls, tl, followan, jfb, yo, fambest, rep,...
# 8   [majestirc, mjs, fambest, sama, shuha, rep, aj...
# 9   [repsusielee, passed, bipartisan, bill, studen...
# 10                                                NaN
#
#                                            Word_Count  Compound  Positive  \
# 0   [(segreenhalgh, 1), (partner, 1), (fsfp, 1), (...   -0.2263    0.0000
# 1   [(msnbc, 1), (referee, 1), (say, 1), (dr, 1), ...    0.0000    0.0000
# 2   [(cloudfess, 1), (cf, 1), (followan, 1), (deng...    0.0000    0.0000
# 3   [(rpautobase, 1), (rpa, 1), (followan, 1), (de...    0.0000    0.0000
# 4   [(cloudfess, 1), (cf, 1), (followan, 1), (deng...    0.0000    0.0000
# 5   [(aja, 2), (majestirc, 1), (mjs, 1), (fambest,...    0.0000    0.0000
# 6   [(rpautobase, 1), (rpa, 1), (followan, 1), (de...    0.0000    0.0000
# 7   [(autotls, 1), (tl, 1), (followan, 1), (jfb, 1...    0.0000    0.0000
# 8   [(aja, 2), (majestirc, 1), (mjs, 1), (fambest,...    0.0000    0.0000
# 9   [(passed, 2), (student, 2), (veteran, 2), (rep...    0.4389    0.1450
# 10                                                NaN       NaN    0.0145
#
#     Negative  Neutral  Compuond
# 0     0.0910   0.9090       NaN
# 1     0.0000   1.0000       NaN
# 2     0.0000   1.0000       NaN
# 3     0.0000   1.0000       NaN
# 4     0.0000   1.0000       NaN
# 5     0.0000   1.0000       NaN
# 6     0.0000   1.0000       NaN
# 7     0.0000   1.0000       NaN
# 8     0.0000   1.0000       NaN
# 9     0.0000   0.8550       NaN
# 10    0.0091   0.9764   0.02126

# %%
test_df = ico_df.iloc[0:3]

# %%
test_df
# Out:
#              Name                                        Description  \
# Ticker
# REP         Augur         Augur is a decentralized prediction market
# LSK          Lisk  It is a cryptocurrency and decentralized appli...
# DGD     Digix DAO  A Decentralized Autonomous Organization focuse...
#
#         Price(USD)               Start                 End  ROI(Pct) Timezone  \
# Ticker
# REP          11.78 2015-08-17 00:00:00 2015-10-01 00:00:00   19.3171    UTC+0
# LSK           0.75 2016-02-22 00:00:00 2016-03-21 00:00:00    9.0686    UTC+0
# DGD          12.06 2016-03-30 12:00:00 2016-03-30 12:00:00    2.7222    UTC+0
#
#        Duration
# Ticker
# REP     45 days
# LSK     28 days
# DGD      0 days

# %%
test_df['Compound'] = ''
test_df['Positive'] = ''
test_df['Negative'] = ''
test_df['Neutral'] = ''
# Out:
# C:\Users\cscat\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\cscat\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\cscat\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\cscat\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
test_df
# Out:
#              Name                                        Description  \
# Ticker
# REP         Augur         Augur is a decentralized prediction market
# LSK          Lisk  It is a cryptocurrency and decentralized appli...
# DGD     Digix DAO  A Decentralized Autonomous Organization focuse...
#
#         Price(USD)               Start                 End  ROI(Pct) Timezone  \
# Ticker
# REP          11.78 2015-08-17 00:00:00 2015-10-01 00:00:00   19.3171    UTC+0
# LSK           0.75 2016-02-22 00:00:00 2016-03-21 00:00:00    9.0686    UTC+0
# DGD          12.06 2016-03-30 12:00:00 2016-03-30 12:00:00    2.7222    UTC+0
#
#        Duration Compound Positive Negative Neutral
# Ticker
# REP     45 days
# LSK     28 days
# DGD      0 days

# %%
test_df.Compound[1] = aug_twittwer_df.Compound.mean()
test_df.Positive[1]= aug_twittwer_df.Positive.mean()
test_df.Negative[1]= aug_twittwer_df.Negative.mean()
test_df.Neutral[1] = aug_twittwer_df.Neutral.mean()
# Out:
# C:\Users\cscat\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\cscat\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3267: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\cscat\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\cscat\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\cscat\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
test_df
# Out:
#              Name                                        Description  \
# Ticker
# REP         Augur         Augur is a decentralized prediction market
# LSK          Lisk  It is a cryptocurrency and decentralized appli...
# DGD     Digix DAO  A Decentralized Autonomous Organization focuse...
#
#         Price(USD)               Start                 End  ROI(Pct) Timezone  \
# Ticker
# REP          11.78 2015-08-17 00:00:00 2015-10-01 00:00:00   19.3171    UTC+0
# LSK           0.75 2016-02-22 00:00:00 2016-03-21 00:00:00    9.0686    UTC+0
# DGD          12.06 2016-03-30 12:00:00 2016-03-30 12:00:00    2.7222    UTC+0
#
#        Duration  Compound Positive Negative Neutral
# Ticker
# REP     45 days   0.02126   0.0145   0.0091  0.9764
# LSK     28 days   0.07364    0.033   0.0114  0.9556
# DGD      0 days   0.02126

# %%
test_df.Negative[1]
# Out:
# 0.0114

# %%
def twitter_df_score(df, N): 
    '''
    Scores an entire Dataframe of coins based on the last 'N' tweets.  Returns a dataframe of scores with a 
    '''
    scores = []
    for name in df.Name:
        search_term = '#' + str(name)
        print(f"Searching and Scoring {search_term}")
        tweet_df = get_twitter_scores(search_term, N)
        score = {name :{
                'Compound' : tweet_df.Compound.mean(),
                'Positive' : tweet_df.Positive.mean(),
                'Negative' : tweet_df.Negative.mean(),
                'Neutral' : tweet_df.Neutral.mean(),
        }}
        scores.append(score)
        print(f"{name} scored")
        for i in progressbar(range(10), "Waiting for Twitter Rate Limit: ", 40):
            time.sleep(0.6) # any calculation you need
    print(f"Scoring of {len(scores)} tweet concluded, creating dataframe")
    
    for item in scores:
        df1=pd.DataFrame.from_dict(item).T
        df2 = pd.concat([df1,df2], sort = True)
#    ndf = pd.concat([df, df2])

    return df2

# %%
twitter_scores = twitter_df_score(ico_df, 20)
# Out:
# Searching and Scoring #Augur
# Augur scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Lisk
# Lisk scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Digix DAO
# Digix DAO scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Waves
# Waves scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Stratis
# Stratis scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Tao Network
# Tao Network scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Incent
# Incent scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #NEO
# NEO scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #BlockPay
# BlockPay scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #FirstBlood
# FirstBlood scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Iconomi
# Iconomi scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Lykke
# Lykke scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Synereo
# Synereo scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #SingularDTV
# SingularDTV scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Beyond The Void
# Beyond The Void scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Decent
# Decent scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Golem
# Golem scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Ark
# Ark scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #vDice.io
# vDice.io scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Komodo
# Komodo scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Golos
# Golos scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #CreativeCoin
# CreativeCoin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Wings
# Wings scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Tokes
# Tokes scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #ChronoBank
# ChronoBank scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Qtum
# Qtum scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Edgeless
# Edgeless scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #iEx.ec
# iEx.ec scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #EncryptoTel
# EncryptoTel scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Gnosis
# Gnosis scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #MobileGo
# MobileGo scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Humaniq
# Humaniq scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Lunyr
# Lunyr scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #TaaS
# TaaS scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #BlockPool
# BlockPool scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #TokenCard
# TokenCard scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #EcoBit
# EcoBit scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #BOScoin
# BOScoin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Blockchain Capital
# Blockchain Capital scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #ZrCoin
# ZrCoin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Aeternity
# Aeternity scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Ethbits
# Ethbits scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Peerplays
# Peerplays scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Aragon
# Aragon scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Monaco
# Monaco scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Storj
# Storj scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Crypviser
# Crypviser scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Quantum RL
# Quantum RL  scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #CryptoPing
# CryptoPing scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Adelphoi
# Adelphoi scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Veritaseum
# Veritaseum scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Mysterium
# Mysterium scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Exscudo
# Exscudo scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Patientory
# Patientory scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Basic Attention Token
# Basic Attention Token scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Wagerr
# Wagerr scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #NVO
# NVO scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Sphre
# Sphre scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Dcorp
# Dcorp scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #GigaWatt
# GigaWatt scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Voise
# Voise scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Omise GO
# Omise GO scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Bancor
# Bancor scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Katalyse
# Katalyse scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Minexcoin
# Minexcoin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Compcoin
# Compcoin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #SONM
# SONM scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Status
# Status scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #21 Million
# 21 Million scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Beth
# Beth scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #OneGram
# OneGram scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Civic
# Civic scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Internet of Coins
# Internet of Coins scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Primalbase
# Primalbase scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #AdToken
# AdToken scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #MyBit
# MyBit scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Bitquence
# Bitquence scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Santiment
# Santiment scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Cofound.it
# Cofound.it scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Metal
# Metal scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #InsureX
# InsureX scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Tezos
# Tezos scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Populous
# Populous scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #TenX
# TenX scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Dent
# Dent scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #district0x
# district0x scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Stox
# Stox scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Starta
# Starta scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #CryptoABS
# CryptoABS scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Suretly
# Suretly scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Hive
# Hive scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #CoinJob
# CoinJob scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #CoinDash
# CoinDash scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Decentraland
# Decentraland scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #0x
# 0x scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Rivet
# Rivet scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Obsidian
# Obsidian scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Corion Platform
# Corion Platform scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #iMPERIUM
# iMPERIUM scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #AICoin
# AICoin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #RasputinOnline Coin
# RasputinOnline Coin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Bowhead
# Bowhead scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #ATB Coin
# ATB Coin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Monetha
# Monetha scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Benjacoin
# Benjacoin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Tron
# Tron scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Arena
# Arena scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Snapup
# Snapup scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #FileCoin
# FileCoin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Hubii Network
# Hubii Network scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Ahoolee
# Ahoolee scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Wild Crypto
# Wild Crypto scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Aventus
# Aventus scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Daseron
# Daseron scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #BitDice
# BitDice scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #ICOBox
# ICOBox scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #KICKICO
# KICKICO scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Umbrella Coin
# Umbrella Coin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Kyber Network
# Kyber Network scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Becksang
# Becksang scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #DetectorToken
# DetectorToken scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Kin
# Kin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Reality Clash
# Reality Clash scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #jNet1
# jNet1 scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Litra Coin
# Litra Coin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #AxionV
# AxionV scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #MoneypotX
# MoneypotX scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Prover
# Prover scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Planes Cloud
# Planes Cloud scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Lust.agency
# Lust.agency scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Power Ledger
# Power Ledger scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #DomRaider
# DomRaider scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #BitJob
# BitJob scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #EventChain
# EventChain scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #HEDGE TOKEN
# HEDGE TOKEN scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Paragon Coin
# Paragon Coin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #DLS Academy
# DLS Academy scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Ethbet
# Ethbet scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Eidoo
# Eidoo scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #DIGI
# DIGI scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #AirToken
# AirToken scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #ChainLink
# ChainLink scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #MyWill Platform
# MyWill Platform scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Flyp.me
# Flyp.me scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #COBINHOOD
# COBINHOOD scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Sex Service
# Sex Service scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Bookira
# Bookira scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #BLOCKv
# BLOCKv scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #CHEX
# CHEX scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #KEY TOKEN
# KEY TOKEN scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Astronaut
# Astronaut scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #ClearPoll
# ClearPoll scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Soma
# Soma scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Swarm Fund
# Swarm Fund scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #LangPie
# LangPie scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Tokenlab
# Tokenlab scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Grant Hero
# Grant Hero scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Cryptopay
# Cryptopay scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Aeron
# Aeron scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Assistive Reality
# Assistive Reality scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #BannerCoin
# BannerCoin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #ATLANT
# ATLANT scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Aldoin
# Aldoin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Dentacoin
# Dentacoin scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Ethino
# Ethino scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Ripio Credit Network
# Ripio Credit Network scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #crypto.tickets
# crypto.tickets scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Utrust
# Utrust scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Starbase
# Starbase scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Qvolta
# Qvolta scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Altocar
# Altocar scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #CryptoHive
# CryptoHive scored
# Waiting for Twitter Rate Limit: [########################################] 10/10
# Searching and Scoring #Blockstack
# Blockstack scored
# Waiting for Twitter Rate Limit: [################........................] 4/10

# %%
def progressbar(it, prefix="", size=60, file=sys.stdout):
    count = len(it)
    def show(j):
        x = int(size*j/count)
        file.write("%s[%s%s] %i/%i\r" % (prefix, "#"*x, "."*(size-x), j, count))
        file.flush()        
    show(0)
    for i, item in enumerate(it):
        yield item
        show(i+1)
    file.write("\n")
    file.flush()

# %%
for i in progressbar(range(6), "Computing: ", 40):
    time.sleep(1) # any calculation you need
# Out:
# Computing: [########################################] 6/6
